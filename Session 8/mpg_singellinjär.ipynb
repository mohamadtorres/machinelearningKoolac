# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("04-MPG.csv")
df.head()
# Out:
#     mpg  fuel_consumption  cylinders  displacement  horsepower  weight  \
# 0  18.0         13.067477          8         307.0         130    3504
# 1  15.0         15.680972          8         350.0         165    3693
# 2  18.0         13.067477          8         318.0         150    3436
# 3  16.0         14.700911          8         304.0         150    3433
# 4  17.0         13.836152          8         302.0         140    3449
#
#    acceleration  year  origin                       name
# 0          12.0    70       1  chevrolet chevelle malibu
# 1          11.5    70       1          buick skylark 320
# 2          11.0    70       1         plymouth satellite
# 3          12.0    70       1              amc rebel sst
# 4          10.5    70       1                ford torino

# %%
#Defining X and Y
#x ba horsepower kar darim
x = df.iloc[:,4].values.reshape(-1,1)
y = df.iloc [:,[1]].values

#be 2 halat mishe reshape(-1,1) kard yekish hamin .reshape(-1,1) hast yeki digash inke [] ezafe konim be [:,-1] va beshe [:-[1]]

# %%
from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,stratify=y,random_state=40)
#chon dige klassifering nis o numerical hast dige stratify nemikhad
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=40)

# %% [markdown]
# mitunim scale nakonim chon inja dige dade ziad nis kollan x ye sotun dare y ham ye sotun o adad ha ham hamchin bozorg nistan pas scale nakonim ham mishe

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()

# x_train = scaler.fit_transform(x_train)

# x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
#inja mige x ke be man midi 1D hast man 2D mikham
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluate =====

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [[ 9.84294841]
#  [ 9.84294841]
#  [11.30497334]
#  [13.02500267]
#  [10.70296307]
#  [ 9.15493667]
#  [ 8.81093081]
#  [15.17503933]
#  [14.14302173]
#  [10.44495867]
#  [10.18695427]
#  [19.47511266]
#  [ 8.03691761]
#  [11.73498067]
#  [10.53096014]
#  [ 8.12291908]
#  [14.31502467]
#  [10.18695427]
#  [ 8.72492934]
#  [17.32507599]
#  [15.0030364 ]
#  [ 8.03691761]
#  [15.17503933]
#  [16.89506866]
#  [ 8.72492934]
#  [18.61509799]
#  [13.88501733]
#  [11.47697627]
#  [14.745032  ]
#  [ 7.86491468]
#  [ 8.46692494]
#  [17.32507599]
#  [ 9.84294841]
#  [14.31502467]
#  [15.17503933]
#  [11.1329704 ]
#  [10.44495867]
#  [ 8.03691761]
#  [11.56297774]
#  [ 9.84294841]
#  [ 8.98293374]
#  [12.59499534]
#  [ 8.46692494]
#  [10.44495867]
#  [ 8.72492934]
#  [11.73498067]
#  [15.17503933]
#  [ 8.63892787]
#  [10.01495134]
#  [ 9.58494401]
#  [11.73498067]
#  [10.10095281]
#  [ 9.75694694]
#  [10.44495867]
#  [10.874966  ]
#  [21.62514932]
#  [ 9.67094547]
#  [ 7.69291174]
#  [20.16312439]
#  [10.01495134]
#  [11.73498067]
#  [21.19514199]
#  [15.17503933]
#  [10.874966  ]
#  [15.17503933]
#  [14.31502467]
#  [11.99298507]
#  [ 8.20892054]
#  [15.60504666]
#  [11.73498067]
#  [18.61509799]
#  [ 8.46692494]
#  [ 8.98293374]
#  [10.01495134]
#  [10.01495134]
#  [10.01495134]
#  [13.45501   ]
#  [ 8.98293374]
#  [12.59499534]
#  [15.17503933]
#  [ 6.40288975]
#  [ 9.75694694]
#  [20.33512732]
#  [ 8.63892787]
#  [ 8.12291908]
#  [13.02500267]
#  [ 9.84294841]
#  [10.874966  ]
#  [11.73498067]
#  [ 9.15493667]
#  [10.874966  ]
#  [ 8.98293374]
#  [10.18695427]
#  [14.4870276 ]
#  [10.61696161]
#  [10.01495134]
#  [11.30497334]
#  [ 8.72492934]]

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# [2.27481935]
# [[0.08600147]]

# %% [markdown]
# # ==== Evaluation ====

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error,r2_score

# %%
mae = mean_absolute_error(y_test,y_pred)
print(f"MAE: {mae}")
mse = mean_squared_error(y_test,y_pred)
print(f"MSE: {mse}")
#rmse
print(f"RMSE: {np.sqrt(mse)}")
mape = mean_absolute_percentage_error(y_test,y_pred)
print(f"MAPE: {mape}")
r2 = r2_score(y_test,y_pred)
print(f"r2: {r2}")
# Out:
# MAE: 1.4911582528726453
# MSE: 3.9802941383827846
# RMSE: 1.9950674520884712
# MAPE: 0.13583544985280208
# r2: 0.753108039177222

# %% [markdown]
# # ===== Visualisation ======

# %%
plt.scatter(y_pred,y_test,color="red")
plt.xlabel("y_pred (Gissade)")
plt.ylabel("y_test (RIktiga)")
plt.show()
#y_pred,y_test mishe tu mehvare ofoghi x biad y_pred vezare tu mehvare amudi y biad y_test bezare

# %% [markdown]
# age hame ina ruye ye khat mishodan ke ali bood ama inja neshon mide cheghad ba vagheyat ke y_test (y_true) hast ma fargh dashtim ke unghadam ziad nis
