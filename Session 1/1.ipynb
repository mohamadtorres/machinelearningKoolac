# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("01-Ad.csv")

# %%
df.shape
# Out:
# (400, 6)

# %%
df.head()
# Out:
#    UserID  Gender Type  Age  EstimatedSalary  Purchased
# 0       1    Male    B   24          2800000          0
# 1       2    Male    A   48          3000000          0
# 2       3  Female    B   34          7800000          0
# 3       4  Female    B   36         10700000          0
# 4       5    Male    D   24         14700000          0

# %% [markdown]
# # nokte
# Model miad inja az UserID och Purchased(target) ke estefade nemikone pas miaim ina ro drop mikonim

# %%
#miam az Age och EstimatedSalary estefade mikonim bara sadegi kar chon adad hast asoon tare
#mamoolan chizayi ke mikham bedim be model ro ba x va chizayi ke mikhaim pishini konim mishe y
#in yaeni kole satrha ama sotun 3 ta 4(khode 5 hesab nemishe)
x = df.iloc[:,3:5].values
#yaeni az in df ke dorost kardi man maghadiresho mikham be esme sotun o in dastana kar nadaram
print(x)
# Out:
# [[      24  2800000]
#  [      48  3000000]
#  [      34  7800000]
#  [      36 10700000]
#  [      24 14700000]
#  [      36 10900000]
#  [      36 16300000]
#  [      44 30000000]
#  [      33  5700000]
#  [      48 12400000]
#  [      34 15500000]
#  [      34  9700000]
#  [      25 16700000]
#  [      44  2600000]
#  [      22 15900000]
#  [      39 15500000]
#  [      67  4100000]
#  [      64  4300000]
#  [      65  4700000]
#  [      68  4900000]
#  [      64  3500000]
#  [      67  9100000]
#  [      68  7400000]
#  [      64  3500000]
#  [      65  3700000]
#  [      67  3000000]
#  [      70  4700000]
#  [      67  5100000]
#  [      39  7800000]
#  [      42  2600000]
#  [      42 14200000]
#  [      36 27300000]
#  [      27  2200000]
#  [      37  8000000]
#  [      36 17600000]
#  [      48  4500000]
#  [      45  4700000]
#  [      41  9100000]
#  [      34 13800000]
#  [      36  5300000]
#  [      36  2400000]
#  [      45  9500000]
#  [      48 21300000]
# ...

# %%
# .values nazari dataframe mishe ke header inash miad ama ba .values mishe ye matrix ba in maghadir
#y = df.iloc[:,5].values
y = df.iloc[:,-1].values
#in rahat tare nemikhad do saat berim beshmorim

# %%
#mamaad
